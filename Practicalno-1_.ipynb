# %%
import pandas as pd
import numpy as np

df = pd.read_csv('gender_submission.csv')

df.head()

df.tail()

df.isnull()

df.isnull().sum()

df.notnull()
df.notnull().sum()

df.describe()

df.columns

df.dtypes

df.dtypes.value_counts()

df.shape
